# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Import Data from Flat file
#CO2 emmissions vs Income Group from Kaggle to corelate data

# %%
CO2_emissions = pd.read_csv(r'C:\Users\Bogdan Nacu\Downloads\CO2_Income_by_country\country_wise_CO2_emissions.csv')
CO2_emissions
# Out:
#                     Country Name Country Code  \
# 0                          Aruba          ABW
# 1    Africa Eastern and Southern          AFE
# 2                    Afghanistan          AFG
# 3     Africa Western and Central          AFW
# 4                         Angola          AGO
# ..                           ...          ...
# 261                       Kosovo          XKX
# 262                  Yemen, Rep.          YEM
# 263                 South Africa          ZAF
# 264                       Zambia          ZMB
# 265                     Zimbabwe          ZWE
#
#                              Indicator Name  Indicator Code        1960  \
# 0    CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC  204.631696
# 1    CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC    0.906060
# 2    CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC    0.046057
# 3    CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC    0.090880
# ...

# %%
CO2_emissions
# Out:
#                     Country Name Country Code  \
# 0                          Aruba          ABW
# 1    Africa Eastern and Southern          AFE
# 2                    Afghanistan          AFG
# 3     Africa Western and Central          AFW
# 4                         Angola          AGO
# ..                           ...          ...
# 261                       Kosovo          XKX
# 262                  Yemen, Rep.          YEM
# 263                 South Africa          ZAF
# 264                       Zambia          ZMB
# 265                     Zimbabwe          ZWE
#
#                              Indicator Name  Indicator Code        1960  \
# 0    CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC  204.631696
# 1    CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC    0.906060
# 2    CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC    0.046057
# 3    CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC    0.090880
# ...

# %%
#Create pandas DataFrame

# %%
CO2_emissions_df = pd.DataFrame(CO2_emissions)

# %%
CO2_emissions_df.head()
# Out:
#                   Country Name Country Code  \
# 0                        Aruba          ABW
# 1  Africa Eastern and Southern          AFE
# 2                  Afghanistan          AFG
# 3   Africa Western and Central          AFW
# 4                       Angola          AGO
#
#                            Indicator Name  Indicator Code        1960  \
# 0  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC  204.631696
# 1  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC    0.906060
# 2  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC    0.046057
# 3  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC    0.090880
# 4  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC    0.100835
#
#          1961        1962        1963        1964        1965  ...      2011  \
# 0  208.837879  226.081890  214.785217  207.626699  185.213644  ...       NaN
# 1    0.922474    0.930816    0.940570    0.996033    1.047280  ...  1.005338
# ...

# %%
Country_income = pd.read_csv(r'C:\Users\Bogdan Nacu\Downloads\CO2_Income_by_country\country_wise_income_group.csv')
Country_income
# Out:
#      Country Name Country Code                      Region  \
# 0           Aruba          ABW   Latin America & Caribbean
# 1     Afghanistan          AFG                  South Asia
# 2          Angola          AGO          Sub-Saharan Africa
# 3         Albania          ALB       Europe & Central Asia
# 4         Andorra          AND       Europe & Central Asia
# ..            ...          ...                         ...
# 243         Samoa          WSM         East Asia & Pacific
# 244   Yemen, Rep.          YEM  Middle East & North Africa
# 245  South Africa          ZAF          Sub-Saharan Africa
# 246        Zambia          ZMB          Sub-Saharan Africa
# 247      Zimbabwe          ZWE          Sub-Saharan Africa
#
#               IncomeGroup                                       SpecialNotes  \
# 0    High income: nonOECD  SNA data for 2000-2011 are updated from offici...
# 1              Low income  Fiscal year end: March 20; reporting period fo...
# ...

# %%
pd.DataFrame(Country_income)
# Out:
#      Country Name Country Code                      Region  \
# 0           Aruba          ABW   Latin America & Caribbean
# 1     Afghanistan          AFG                  South Asia
# 2          Angola          AGO          Sub-Saharan Africa
# 3         Albania          ALB       Europe & Central Asia
# 4         Andorra          AND       Europe & Central Asia
# ..            ...          ...                         ...
# 243         Samoa          WSM         East Asia & Pacific
# 244   Yemen, Rep.          YEM  Middle East & North Africa
# 245  South Africa          ZAF          Sub-Saharan Africa
# 246        Zambia          ZMB          Sub-Saharan Africa
# 247      Zimbabwe          ZWE          Sub-Saharan Africa
#
#               IncomeGroup                                       SpecialNotes  \
# 0    High income: nonOECD  SNA data for 2000-2011 are updated from offici...
# 1              Low income  Fiscal year end: March 20; reporting period fo...
# ...

# %%
Country_income.head()
# Out:
#   Country Name Country Code                     Region           IncomeGroup  \
# 0        Aruba          ABW  Latin America & Caribbean  High income: nonOECD
# 1  Afghanistan          AFG                 South Asia            Low income
# 2       Angola          AGO         Sub-Saharan Africa   Upper middle income
# 3      Albania          ALB      Europe & Central Asia   Upper middle income
# 4      Andorra          AND      Europe & Central Asia  High income: nonOECD
#
#                                         SpecialNotes  Unnamed: 5
# 0  SNA data for 2000-2011 are updated from offici...         NaN
# 1  Fiscal year end: March 20; reporting period fo...         NaN
# 2  April 2013 database update: Based on IMF data,...         NaN
# 3                                                NaN         NaN
# 4                                                NaN         NaN

# %%
pwd
# Out:
# 'C:\\Users\\Bogdan Nacu\\Desktop\\Data_Analytics_Project\\UCD'

# %%
#Exemplifying Numoy functions

# %%
CO2_emissions[['1960', '2018']].apply(np.sum)
# Out:
# 1960    641.524584
# 2018    993.730805
# dtype: float64

# %%
CO2_emissions['Sum_60_18'] = CO2_emissions[['1960', '2018']].apply(np.sum, axis=1)

# %%
CO2_emissions.head()
# Out:
#                   Country Name Country Code  \
# 0                        Aruba          ABW
# 1  Africa Eastern and Southern          AFE
# 2                  Afghanistan          AFG
# 3   Africa Western and Central          AFW
# 4                       Angola          AGO
#
#                            Indicator Name  Indicator Code        1960  \
# 0  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC  204.631696
# 1  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC    0.906060
# 2  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC    0.046057
# 3  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC    0.090880
# 4  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC    0.100835
#
#          1961        1962        1963        1964        1965  ...      2012  \
# 0  208.837879  226.081890  214.785217  207.626699  185.213644  ...       NaN
# 1    0.922474    0.930816    0.940570    0.996033    1.047280  ...  1.021646
# ...

# %%
#I defined a Custom function to create reusable code. Average CO2 emissions for each country

# %%
def Average_emissions(CO2_emissions_df):
    Average_emissions = CO2_emissions_df.mean(numeric_only=True, axis=1)
    return Average_emissions

# %%
Average_emissions(CO2_emissions_df)
# Out:
# 0      184.742792
# 1        1.101909
# 2        0.150996
# 3        0.443454
# 4        0.692552
#           ...
# 261      0.000000
# 262      0.440390
# 263      7.592907
# 264      0.479331
# 265      1.195681
# Length: 266, dtype: float64

# %%
CO2_emissions_df['Average_emissions_metric_tons_per_capita'] = Average_emissions(CO2_emissions_df)

# %%
CO2_emissions_df
# Out:
#                     Country Name Country Code  \
# 0                          Aruba          ABW
# 1    Africa Eastern and Southern          AFE
# 2                    Afghanistan          AFG
# 3     Africa Western and Central          AFW
# 4                         Angola          AGO
# ..                           ...          ...
# 261                       Kosovo          XKX
# 262                  Yemen, Rep.          YEM
# 263                 South Africa          ZAF
# 264                       Zambia          ZMB
# 265                     Zimbabwe          ZWE
#
#                              Indicator Name  Indicator Code        1960  \
# 0    CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC  204.631696
# 1    CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC    0.906060
# 2    CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC    0.046057
# 3    CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC    0.090880
# ...

# %%
#Checking details of the data frames

# %%
CO2_emissions_df.info
# Out:
# <bound method DataFrame.info of                     Country Name Country Code  \
# 0                          Aruba          ABW
# 1    Africa Eastern and Southern          AFE
# 2                    Afghanistan          AFG
# 3     Africa Western and Central          AFW
# 4                         Angola          AGO
# ..                           ...          ...
# 261                       Kosovo          XKX
# 262                  Yemen, Rep.          YEM
# 263                 South Africa          ZAF
# 264                       Zambia          ZMB
# 265                     Zimbabwe          ZWE
#
#                              Indicator Name  Indicator Code        1960  \
# 0    CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC  204.631696
# 1    CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC    0.906060
# 2    CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC    0.046057
# 3    CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC    0.090880
# ...

# %%
Country_income.info
# Out:
# <bound method DataFrame.info of      Country Name Country Code                      Region  \
# 0           Aruba          ABW   Latin America & Caribbean
# 1     Afghanistan          AFG                  South Asia
# 2          Angola          AGO          Sub-Saharan Africa
# 3         Albania          ALB       Europe & Central Asia
# 4         Andorra          AND       Europe & Central Asia
# ..            ...          ...                         ...
# 243         Samoa          WSM         East Asia & Pacific
# 244   Yemen, Rep.          YEM  Middle East & North Africa
# 245  South Africa          ZAF          Sub-Saharan Africa
# 246        Zambia          ZMB          Sub-Saharan Africa
# 247      Zimbabwe          ZWE          Sub-Saharan Africa
#
#               IncomeGroup                                       SpecialNotes  \
# 0    High income: nonOECD  SNA data for 2000-2011 are updated from offici...
# ...

# %%
#Exemplifying indexing. Selecting specific columns and data

# %%
CO2_emissions_df.index
# Out:
# RangeIndex(start=0, stop=266, step=1)

# %%
Country_income.index
# Out:
# RangeIndex(start=0, stop=248, step=1)

# %%
CO2_emissions_df.iloc[0, 6]
# Out:
# 226.08189

# %%
Country_income[0:5]
# Out:
#   Country Name Country Code                     Region           IncomeGroup  \
# 0        Aruba          ABW  Latin America & Caribbean  High income: nonOECD
# 1  Afghanistan          AFG                 South Asia            Low income
# 2       Angola          AGO         Sub-Saharan Africa   Upper middle income
# 3      Albania          ALB      Europe & Central Asia   Upper middle income
# 4      Andorra          AND      Europe & Central Asia  High income: nonOECD
#
#                                         SpecialNotes  Unnamed: 5
# 0  SNA data for 2000-2011 are updated from offici...         NaN
# 1  Fiscal year end: March 20; reporting period fo...         NaN
# 2  April 2013 database update: Based on IMF data,...         NaN
# 3                                                NaN         NaN
# 4                                                NaN         NaN

# %%
CO2_emissions_df[0: ][['Country Name', '1960', '1980', '2000', '2018']]
# Out:
#                     Country Name        1960        1980      2000      2018
# 0                          Aruba  204.631696  174.694594       NaN       NaN
# 1    Africa Eastern and Southern    0.906060    1.235911  0.900399  0.933541
# 2                    Afghanistan    0.046057    0.131783  0.037055  0.200151
# 3     Africa Western and Central    0.090880    0.634541  0.447244  0.515544
# 4                         Angola    0.100835    0.640966  0.754476  0.887380
# ..                           ...         ...         ...       ...       ...
# 261                       Kosovo         NaN         NaN       NaN       NaN
# 262                  Yemen, Rep.    0.011038    0.150523  0.797860  0.326682
# 263                 South Africa    5.727223    7.999998  6.331876  7.496645
# 264                       Zambia         NaN    0.603457  0.173772  0.446065
# 265                     Zimbabwe         NaN    1.300764  1.153055  0.849793
#
# [266 rows x 5 columns]

# %%
#Drop duplicates

# %%
CO2_emissions_df.drop_duplicates
# Out:
# <bound method DataFrame.drop_duplicates of                     Country Name Country Code  \
# 0                          Aruba          ABW
# 1    Africa Eastern and Southern          AFE
# 2                    Afghanistan          AFG
# 3     Africa Western and Central          AFW
# 4                         Angola          AGO
# ..                           ...          ...
# 261                       Kosovo          XKX
# 262                  Yemen, Rep.          YEM
# 263                 South Africa          ZAF
# 264                       Zambia          ZMB
# 265                     Zimbabwe          ZWE
#
#                              Indicator Name  Indicator Code        1960  \
# 0    CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC  204.631696
# 1    CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC    0.906060
# 2    CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC    0.046057
# 3    CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC    0.090880
# ...

# %%
Country_income.drop_duplicates
# Out:
# <bound method DataFrame.drop_duplicates of      Country Name Country Code                      Region  \
# 0           Aruba          ABW   Latin America & Caribbean
# 1     Afghanistan          AFG                  South Asia
# 2          Angola          AGO          Sub-Saharan Africa
# 3         Albania          ALB       Europe & Central Asia
# 4         Andorra          AND       Europe & Central Asia
# ..            ...          ...                         ...
# 243         Samoa          WSM         East Asia & Pacific
# 244   Yemen, Rep.          YEM  Middle East & North Africa
# 245  South Africa          ZAF          Sub-Saharan Africa
# 246        Zambia          ZMB          Sub-Saharan Africa
# 247      Zimbabwe          ZWE          Sub-Saharan Africa
#
#               IncomeGroup                                       SpecialNotes  \
# 0    High income: nonOECD  SNA data for 2000-2011 are updated from offici...
# ...

# %%
#Replacing missing values, Handling Nulls
#2019 & 2020 there is no available data for CO2 
#There is an "Unnamed: 5" Column in the Country income table with no data

# %%
CO2_emissions.isnull().sum()
# Out:
# Country Name                                  0
# Country Code                                  0
# Indicator Name                                0
# Indicator Code                                0
# 1960                                         63
#                                            ...
# 2018                                         27
# 2019                                        266
# 2020                                        266
# Sum_60_18                                     0
# Average_emissions_metric_tons_per_capita      0
# Length: 67, dtype: int64

# %%
Country_income.isnull().sum()
# Out:
# Country Name      0
# Country Code      0
# Region           33
# IncomeGroup      33
# SpecialNotes     79
# Unnamed: 5      248
# dtype: int64

# %%
CO2_emissions_df.dropna(axis=1, how='all').shape
# Out:
# (266, 65)

# %%
CO2_emissions_df.dropna(axis=1, how='all', inplace = True)

# %%
CO2_emissions_df.dropna()
# Out:
#                     Country Name Country Code  \
# 1    Africa Eastern and Southern          AFE
# 2                    Afghanistan          AFG
# 3     Africa Western and Central          AFW
# 4                         Angola          AGO
# 5                        Albania          ALB
# ..                           ...          ...
# 257                      Vietnam          VNM
# 259                        World          WLD
# 260                        Samoa          WSM
# 262                  Yemen, Rep.          YEM
# 263                 South Africa          ZAF
#
#                              Indicator Name  Indicator Code      1960  \
# 1    CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC  0.906060
# 2    CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC  0.046057
# 3    CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC  0.090880
# 4    CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC  0.100835
# ...

# %%
#Removing the Unnamed Column

# %%
Country_income.dropna(axis=1, how='all', inplace = True)

# %%
Country_income
# Out:
#      Country Name Country Code                      Region  \
# 0           Aruba          ABW   Latin America & Caribbean
# 1     Afghanistan          AFG                  South Asia
# 2          Angola          AGO          Sub-Saharan Africa
# 3         Albania          ALB       Europe & Central Asia
# 4         Andorra          AND       Europe & Central Asia
# ..            ...          ...                         ...
# 243         Samoa          WSM         East Asia & Pacific
# 244   Yemen, Rep.          YEM  Middle East & North Africa
# 245  South Africa          ZAF          Sub-Saharan Africa
# 246        Zambia          ZMB          Sub-Saharan Africa
# 247      Zimbabwe          ZWE          Sub-Saharan Africa
#
#               IncomeGroup                                       SpecialNotes
# 0    High income: nonOECD  SNA data for 2000-2011 are updated from offici...
# 1              Low income  Fiscal year end: March 20; reporting period fo...
# ...

# %%
#Keeping only Rows from IncomeGroup column where information is available

# %%
Country_income = Country_income[Country_income['IncomeGroup'].notna()]

# %%
Country_income
# Out:
#      Country Name Country Code                      Region  \
# 0           Aruba          ABW   Latin America & Caribbean
# 1     Afghanistan          AFG                  South Asia
# 2          Angola          AGO          Sub-Saharan Africa
# 3         Albania          ALB       Europe & Central Asia
# 4         Andorra          AND       Europe & Central Asia
# ..            ...          ...                         ...
# 243         Samoa          WSM         East Asia & Pacific
# 244   Yemen, Rep.          YEM  Middle East & North Africa
# 245  South Africa          ZAF          Sub-Saharan Africa
# 246        Zambia          ZMB          Sub-Saharan Africa
# 247      Zimbabwe          ZWE          Sub-Saharan Africa
#
#               IncomeGroup                                       SpecialNotes
# 0    High income: nonOECD  SNA data for 2000-2011 are updated from offici...
# 1              Low income  Fiscal year end: March 20; reporting period fo...
# ...

# %%
Country_income['IncomeGroup']
# Out:
# 0      High income: nonOECD
# 1                Low income
# 2       Upper middle income
# 3       Upper middle income
# 4      High income: nonOECD
#                ...
# 243     Lower middle income
# 244     Lower middle income
# 245     Upper middle income
# 246     Lower middle income
# 247              Low income
# Name: IncomeGroup, Length: 215, dtype: object

# %%
Country_income['IncomeGroup'].isnull().sum()
# Out:
# 0

# %%
#Exemplifying replacing missing data from CO2 table data with "No Data Available message"

# %%
CO2_emissions.fillna(method='bfill', axis=1).fillna('No Data Available')
# Out:
#                     Country Name Country Code  \
# 0                          Aruba          ABW
# 1    Africa Eastern and Southern          AFE
# 2                    Afghanistan          AFG
# 3     Africa Western and Central          AFW
# 4                         Angola          AGO
# ..                           ...          ...
# 261                       Kosovo          XKX
# 262                  Yemen, Rep.          YEM
# 263                 South Africa          ZAF
# 264                       Zambia          ZMB
# 265                     Zimbabwe          ZWE
#
#                              Indicator Name  Indicator Code        1960  \
# 0    CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC  204.631696
# 1    CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC    0.906060
# 2    CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC    0.046057
# 3    CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC    0.090880
# ...

# %%
Country_income.fillna(method='bfill', axis=1).fillna('No Data Available')
# Out:
#      Country Name Country Code                      Region  \
# 0           Aruba          ABW   Latin America & Caribbean
# 1     Afghanistan          AFG                  South Asia
# 2          Angola          AGO          Sub-Saharan Africa
# 3         Albania          ALB       Europe & Central Asia
# 4         Andorra          AND       Europe & Central Asia
# ..            ...          ...                         ...
# 243         Samoa          WSM         East Asia & Pacific
# 244   Yemen, Rep.          YEM  Middle East & North Africa
# 245  South Africa          ZAF          Sub-Saharan Africa
# 246        Zambia          ZMB          Sub-Saharan Africa
# 247      Zimbabwe          ZWE          Sub-Saharan Africa
#
#               IncomeGroup                                       SpecialNotes
# 0    High income: nonOECD  SNA data for 2000-2011 are updated from offici...
# 1              Low income  Fiscal year end: March 20; reporting period fo...
# ...

# %%
#I started to work on generating a view of the average emissions by region, corelated with income group

# %%
CO2_emissions_df.dropna()
# Out:
#                     Country Name Country Code  \
# 1    Africa Eastern and Southern          AFE
# 2                    Afghanistan          AFG
# 3     Africa Western and Central          AFW
# 4                         Angola          AGO
# 5                        Albania          ALB
# ..                           ...          ...
# 257                      Vietnam          VNM
# 259                        World          WLD
# 260                        Samoa          WSM
# 262                  Yemen, Rep.          YEM
# 263                 South Africa          ZAF
#
#                              Indicator Name  Indicator Code      1960  \
# 1    CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC  0.906060
# 2    CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC  0.046057
# 3    CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC  0.090880
# 4    CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC  0.100835
# ...

# %%
#I tried to transpose the data to generate a graph, but I didn't succeed generating the graph I wanted

# %%
CO2_transposed = CO2_emissions.transpose()

# %%
CO2_transposed.dropna(axis=1, how='all', inplace = True)

# %%
CO2_transposed
# Out:
#                                                                              0    \
# Country Name                                                               Aruba
# Country Code                                                                 ABW
# Indicator Name                            CO2 emissions (metric tons per capita)
# Indicator Code                                                    EN.ATM.CO2E.PC
# 1960                                                                  204.631696
# ...                                                                          ...
# 2018                                                                         NaN
# 2019                                                                         NaN
# 2020                                                                         NaN
# Sum_60_18                                                             204.631696
# Average_emissions_metric_tons_per_capita                              184.742792
# ...

# %%
sns.scatterplot(x='Indicator Code',y='Average_emissions_metric_tons_per_capita', data=CO2_emissions)
# Out:
# <AxesSubplot:xlabel='Indicator Code', ylabel='Average_emissions_metric_tons_per_capita'>

# %%
#Merging Data Frames CO2 emissions with Income Group with "Country Name" as key
#Income group has been added for each country where data is available

# %%
Merged_df = CO2_emissions_df.merge(Country_income)

# %%
Merged_df
# Out:
#      Country Name Country Code                          Indicator Name  \
# 0           Aruba          ABW  CO2 emissions (metric tons per capita)
# 1     Afghanistan          AFG  CO2 emissions (metric tons per capita)
# 2          Angola          AGO  CO2 emissions (metric tons per capita)
# 3         Albania          ALB  CO2 emissions (metric tons per capita)
# 4         Andorra          AND  CO2 emissions (metric tons per capita)
# ..            ...          ...                                     ...
# 201         Samoa          WSM  CO2 emissions (metric tons per capita)
# 202   Yemen, Rep.          YEM  CO2 emissions (metric tons per capita)
# 203  South Africa          ZAF  CO2 emissions (metric tons per capita)
# 204        Zambia          ZMB  CO2 emissions (metric tons per capita)
# 205      Zimbabwe          ZWE  CO2 emissions (metric tons per capita)
#
#      Indicator Code        1960        1961        1962        1963  \
# ...

# %%
#Selecting only the columns that have all data available and removing NaN
#Isolating average emissions for each country for the whole period 1960-2018

# %%
Relevant_data = Merged_df[['Country Name', 'Average_emissions_metric_tons_per_capita', 'Region', 'IncomeGroup']]

# %%
Relevant_data
# Out:
#      Country Name  Average_emissions_metric_tons_per_capita  \
# 0           Aruba                                184.742792
# 1     Afghanistan                                  0.150996
# 2          Angola                                  0.692552
# 3         Albania                                  1.686058
# 4         Andorra                                  6.751327
# ..            ...                                       ...
# 201         Samoa                                  0.710907
# 202   Yemen, Rep.                                  0.440390
# 203  South Africa                                  7.592907
# 204        Zambia                                  0.479331
# 205      Zimbabwe                                  1.195681
#
#                          Region           IncomeGroup
# 0     Latin America & Caribbean  High income: nonOECD
# 1                    South Asia            Low income
# 2            Sub-Saharan Africa   Upper middle income
# ...

# %%
Relevant_data.isnull().sum()
# Out:
# Country Name                                0
# Average_emissions_metric_tons_per_capita    0
# Region                                      0
# IncomeGroup                                 0
# dtype: int64

# %%
Final_data = Relevant_data.dropna()

# %%
Final_data
# Out:
#      Country Name  Average_emissions_metric_tons_per_capita  \
# 0           Aruba                                184.742792
# 1     Afghanistan                                  0.150996
# 2          Angola                                  0.692552
# 3         Albania                                  1.686058
# 4         Andorra                                  6.751327
# ..            ...                                       ...
# 201         Samoa                                  0.710907
# 202   Yemen, Rep.                                  0.440390
# 203  South Africa                                  7.592907
# 204        Zambia                                  0.479331
# 205      Zimbabwe                                  1.195681
#
#                          Region           IncomeGroup
# 0     Latin America & Caribbean  High income: nonOECD
# 1                    South Asia            Low income
# 2            Sub-Saharan Africa   Upper middle income
# ...

# %%
Final_data.isnull().sum()
# Out:
# Country Name                                0
# Average_emissions_metric_tons_per_capita    0
# Region                                      0
# IncomeGroup                                 0
# dtype: int64

# %%
#I wanted to see if there is a corelation between Region, Income Group and average CO2 emissions/capita between 1960-2018
#There is a direct corelation between income and CO2 levels/capita as seen below: High income countries have the highest CO2 emissions
#Middle East & North Africa stands out as the region with the most countries that have high CO2 emissions/capita(3 countries with over 25 metric tons/capita)

# %%
sns.scatterplot(x='Average_emissions_metric_tons_per_capita', y='Region', data=Final_data, hue='IncomeGroup', size='Average_emissions_metric_tons_per_capita').set(title='Average CO2 emissions by region 1960 to 2018')
# Out:
# [Text(0.5, 1.0, 'Average CO2 emissions by region 1960 to 2018')]

# %%
#Look at overall CO2 emissions/capita from 1960-2018 to see trend and predict future evolution
#I chose specific years (decades) so the data is easier to read in the graph

# %%
Trend = CO2_emissions_df[0: ][['Country Name', '1960', '1970', '1980', '1990', '2000', '2010', '2018']]

# %%
Trend
# Out:
#                     Country Name        1960        1970        1980  \
# 0                          Aruba  204.631696  281.962316  174.694594
# 1    Africa Eastern and Southern    0.906060    1.123261    1.235911
# 2                    Afghanistan    0.046057    0.149651    0.131783
# 3     Africa Western and Central    0.090880    0.302643    0.634541
# 4                         Angola    0.100835    0.608224    0.640966
# ..                           ...         ...         ...         ...
# 261                       Kosovo         NaN         NaN         NaN
# 262                  Yemen, Rep.    0.011038    0.027236    0.150523
# 263                 South Africa    5.727223    6.785927    7.999998
# 264                       Zambia         NaN    0.902039    0.603457
# 265                     Zimbabwe         NaN    1.543252    1.300764
#
#          1990      2000      2010      2018
# 0         NaN       NaN       NaN       NaN
# 1    1.017505  0.900399  1.048876  0.933541
# ...

# %%
Trend.isnull().sum()
# Out:
# Country Name     0
# 1960            63
# 1970            52
# 1980            50
# 1990            28
# 2000            27
# 2010            27
# 2018            27
# dtype: int64

# %%
Trend_cleaned = Trend.dropna()

# %%
Trend_cleaned.isnull().sum()
# Out:
# Country Name    0
# 1960            0
# 1970            0
# 1980            0
# 1990            0
# 2000            0
# 2010            0
# 2018            0
# dtype: int64

# %%
Trend_cleaned.index
# Out:
# Int64Index([  1,   2,   3,   4,   5,   7,   8,   9,  12,  13,
#             ...
#             249, 250, 251, 253, 254, 257, 259, 260, 262, 263],
#            dtype='int64', length=193)

# %%
#I cleaned the data and kept only the Countries for which information was available in all years for an accurate comparison
#73 columns were removed as data was not available for all countries

# %%
Trend_cleaned
# Out:
#                     Country Name      1960      1970      1980      1990  \
# 1    Africa Eastern and Southern  0.906060  1.123261  1.235911  1.017505
# 2                    Afghanistan  0.046057  0.149651  0.131783  0.238473
# 3     Africa Western and Central  0.090880  0.302643  0.634541  0.440470
# 4                         Angola  0.100835  0.608224  0.640966  0.534250
# 5                        Albania  1.258195  1.753240  1.935058  1.840841
# ..                           ...       ...       ...       ...       ...
# 257                      Vietnam  0.181947  0.649680  0.309874  0.270780
# 259                        World  3.121158  4.147851  4.601082  3.902952
# 260                        Samoa  0.135031  0.204938  0.636624  0.675688
# 262                  Yemen, Rep.  0.011038  0.027236  0.150523  0.567037
# 263                 South Africa  5.727223  6.785927  7.999998  6.729799
#
#          2000      2010      2018
# 1    0.900399  1.048876  0.933541
# ...

# %%
#I added CO2_emissions for all countries in each year using the sum function

# %%
Trend_1 = Trend_cleaned.apply(np.sum)

# %%
Trend_1
# Out:
# Country Name    Africa Eastern and SouthernAfghanistanAfrica W...
# 1960                                                   408.686218
# 1970                                                   863.338978
# 1980                                                     928.5333
# 1990                                                   742.582403
# 2000                                                   788.097872
# 2010                                                     843.5917
# 2018                                                   800.294024
# dtype: object

# %%
#I created a Data Frame for easier manipulation

# %%
Trend_2 = pd.DataFrame(Trend_1)

# %%
Trend_2
# Out:
#                                                               0
# Country Name  Africa Eastern and SouthernAfghanistanAfrica W...
# 1960                                                 408.686218
# 1970                                                 863.338978
# 1980                                                   928.5333
# 1990                                                 742.582403
# 2000                                                 788.097872
# 2010                                                   843.5917
# 2018                                                 800.294024

# %%
#I created a Data Frame from 2 lists, using the above data, as I didn't know how to add the index in order to have 2 columns

# %%
Year =["1960", "1970", "1980", "1990", "2000", "2010", "2018"]
World_emissions =["408.68", "863.33", "928.53", "742.58", "788.09", "843.59", "800.29"]

# %%
World_CO2_emissions = pd.DataFrame(list(zip(Year, World_emissions)))

# %%
World_CO2_emissions
# Out:
#       0       1
# 0  1960  408.68
# 1  1970  863.33
# 2  1980  928.53
# 3  1990  742.58
# 4  2000  788.09
# 5  2010  843.59
# 6  2018  800.29

# %%
#I renamed the Columns in the Data Frame

# %%
World_CO2_emissions.rename(columns={World_CO2_emissions.columns[0]: 'Year', World_CO2_emissions.columns[1]: 'CO2_metric_tons_capita'},inplace=True)

# %%
World_CO2_emissions
# Out:
#    Year CO2_metric_tons_capita
# 0  1960                 408.68
# 1  1970                 863.33
# 2  1980                 928.53
# 3  1990                 742.58
# 4  2000                 788.09
# 5  2010                 843.59
# 6  2018                 800.29

# %%
#I changed the Year data to datetime so I can see an evolution in time in the graph

# %%
World_CO2_emissions['Year'] = pd.to_datetime(World_CO2_emissions['Year'])

# %%
World_CO2_emissions
# Out:
#         Year CO2_metric_tons_capita
# 0 1960-01-01                 408.68
# 1 1970-01-01                 863.33
# 2 1980-01-01                 928.53
# 3 1990-01-01                 742.58
# 4 2000-01-01                 788.09
# 5 2010-01-01                 843.59
# 6 2018-01-01                 800.29

# %%
World_CO2_emissions.set_index('Year', inplace=True)

# %%
World_CO2_emissions.dtypes
# Out:
# CO2_metric_tons_capita    object
# dtype: object

# %%
#Converting the CO2_metric_tons_capita Column to float so that we can generate a relevant graph. 
#I received an error that no numeric data to plot when trying to generate a graph initially
#We see a decreasing trend in the last decade in terms of CO2 emissions/capita worldwide. Almost back to the 1990 data. This could be related to the efforts the countries make to reduce polution

# %%
World_CO2_emissions['CO2_metric_tons_capita']=World_CO2_emissions['CO2_metric_tons_capita'].astype(float)

# %%
sns.lineplot(data=World_CO2_emissions, x='Year', y='CO2_metric_tons_capita').set(title='World CO2 Emissions trend')
# Out:
# [Text(0.5, 1.0, 'World CO2 Emissions trend')]

# %%
#I tried to Import data using API from Twitter below. 
#I wanted to get the number of tweets mentioning #globalwarming in the last 7 days, to show it is a widespread topic on social media but didn't suceed
#I created a developer account on Twitter, but didn't manage to write the right code to get the data
#I exemplified below how data can be pulled out using API from an open source

# %%
import requests
import os
import json

# %%
bearer_token = os.environ.get("AAAAAAAAAAAAAAAAAAAAABz7lQEAAAAALoeQVMCLrCW7wUbJBY7WgvSgAxE%3Dkvw3bDHO5OcLxZd85u9uYDUJRSx0dWjW0WwrWqoXikOQxlE0bs")

# %%
search_url = "https://api.twitter.com/2/tweets/counts/recent"

# %%
# Optional params: start_time,end_time,since_id,until_id,next_token,granularity

# %%
query_params = {'query': 'from:twitterdev','granularity': 'day'}

# %%
def bearer_oauth(r):
    """
    Method required by bearer token authentication.
    """

    r.headers["Authorization"] = f"Bearer {bearer_token}"
    r.headers["User-Agent"] = "v2RecentTweetCountsPython"
    return r

# %%
def connect_to_endpoint(url, params):
    tweets_gw = requests.get(https://twitter.com/search?q=%23globalwarming&src=typeahead_click&f=live, auth=bearer_oauth, params=params)
    print(tweets_gw.status_code)
    if tweets_gw.status_code != 200:
        raise Exception(tweets_gw.status_code, tweets_gw.text)
    return tweets_gw.json()
# Out:
#   File "<ipython-input-116-b41bfa174bf4>", line 2
#     tweets_gw = requests.get(https://twitter.com/search?q=%23globalwarming&src=typeahead_click&f=live, auth=bearer_oauth, params=params)
#                                   ^
# SyntaxError: invalid syntax

# %%
def main():
    json_tweets_gw = connect_to_endpoint(search_url, query_params)
    print(json.dumps(json_, indent=4, sort_keys=True))

# %%
if __name__ == "globalwarming":
    globalwarming()

# %%
#Exemplifying how to pull data using API from a source where no Authentification was needed. 
#The data shows the carbon intensity of the electricity system in Great Britain in the last 30 minutes and a forecast up to 2 days ahead of real-time
#The Carbon Intensity forecast includes CO2 emissions related to electricity generation only:emissions from all large metered power stations, interconnector imports, transmission and distribution losses

# %%
import requests
headers = {
  'Accept': 'application/json'
}
 
r = requests.get('https://api.carbonintensity.org.uk/intensity', params={}, headers = headers)
 
r.json()
# Out:
# {'data': [{'from': '2023-01-31T19:30Z',
#    'to': '2023-01-31T20:00Z',
#    'intensity': {'forecast': 146, 'actual': 161, 'index': 'moderate'}}]}

# %%
pd.DataFrame(r.json())
# Out:
#                                                 data
# 0  {'from': '2023-01-31T19:30Z', 'to': '2023-01-3...

# %%
#Grouping data by Region to see which had the higher total emissions throughout the period

# %%
Groupby_Region = Merged_df.drop(columns=["Average_emissions_metric_tons_per_capita", "SpecialNotes", "Sum_60_18"])

# %%
Groupby_Region
# Out:
#      Country Name Country Code                          Indicator Name  \
# 0           Aruba          ABW  CO2 emissions (metric tons per capita)
# 1     Afghanistan          AFG  CO2 emissions (metric tons per capita)
# 2          Angola          AGO  CO2 emissions (metric tons per capita)
# 3         Albania          ALB  CO2 emissions (metric tons per capita)
# 4         Andorra          AND  CO2 emissions (metric tons per capita)
# ..            ...          ...                                     ...
# 201         Samoa          WSM  CO2 emissions (metric tons per capita)
# 202   Yemen, Rep.          YEM  CO2 emissions (metric tons per capita)
# 203  South Africa          ZAF  CO2 emissions (metric tons per capita)
# 204        Zambia          ZMB  CO2 emissions (metric tons per capita)
# 205      Zimbabwe          ZWE  CO2 emissions (metric tons per capita)
#
#      Indicator Code        1960        1961        1962        1963  \
# ...

# %%
Group_by_Region_1 = Groupby_Region.dropna()

# %%
Group_by_Region_1
# Out:
#              Country Name Country Code  \
# 1             Afghanistan          AFG
# 2                  Angola          AGO
# 3                 Albania          ALB
# 5    United Arab Emirates          ARE
# 6               Argentina          ARG
# ..                    ...          ...
# 197         Venezuela, RB          VEN
# 199               Vietnam          VNM
# 201                 Samoa          WSM
# 202           Yemen, Rep.          YEM
# 203          South Africa          ZAF
#
#                              Indicator Name  Indicator Code      1960  \
# 1    CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC  0.046057
# 2    CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC  0.100835
# 3    CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC  1.258195
# 5    CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC  0.119037
# 6    CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC  2.383343
# ...

# %%
Group_by_Region_1.groupby('Region')

# %%
Group_by_Region_1['Total_emissions'] = Group_by_Region_1.sum(axis=1)
# Out:
# <ipython-input-166-76a09c97a9f2>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Group_by_Region_1['Total_emissions'] = Group_by_Region_1.sum(axis=1)

# %%
Group_by_Region_1.groupby(['Region']).sum()
# Out:
#                                   1960        1961        1962        1963  \
# Region
# East Asia & Pacific          27.906958   31.820662   33.075338   34.234657
# Europe & Central Asia       147.412045  149.765514  156.762131  164.757300
# Latin America & Caribbean    35.631938   38.882279   45.308819   37.654642
# Middle East & North Africa   20.751500   27.848250   27.637536  122.469489
# North America                26.770626   26.309153   27.144565   27.614865
# South Asia                    1.159864    1.191262    1.294172    1.381704
# Sub-Saharan Africa            9.565600    9.708167    9.824674   10.001837
#
#                                   1964        1965        1966        1967  \
# Region
# East Asia & Pacific          36.400782   37.201625   37.738929   40.397747
# Europe & Central Asia       172.702982  176.328255  181.833926  182.721809
# Latin America & Caribbean    45.384423   50.525757   52.251410   62.441707
# ...

# %%
Group_by_Region_1.groupby('Region').sum()['Total_emissions'].plot.bar()
plt.xlabel('Region')
plt.ylabel('metric tons/ capita')
plt.title('Total per capita CO2 emissions 1960-2018 by Region')
# Out:
# Text(0.5, 1.0, 'Total per capita CO2 emissions 1960-2018 by Region')

# %%
#Average emissions by region

# %%
Final_data.groupby('Region')

# %%
Final_data.groupby(['Region']).sum()
# Out:
#                             Average_emissions_metric_tons_per_capita
# Region
# East Asia & Pacific                                       119.097325
# Europe & Central Asia                                     352.944851
# Latin America & Caribbean                                 277.701168
# Middle East & North Africa                                184.053737
# North America                                              41.372056
# South Asia                                                  4.187083
# Sub-Saharan Africa                                         33.637015

# %%
#Number of Countries in each region

# %%
sns.countplot(data=Final_data, y='Region').set(title='Number of countries for each region')
# Out:
# [Text(0.5, 1.0, 'Number of countries for each region')]

# %%
#Sorting by the countries with the highest CO2 emissions/capita for the period

# %%
pd.DataFrame(Group_by_Region_1)
# Out:
#              Country Name Country Code  \
# 1             Afghanistan          AFG
# 2                  Angola          AGO
# 3                 Albania          ALB
# 5    United Arab Emirates          ARE
# 6               Argentina          ARG
# ..                    ...          ...
# 197         Venezuela, RB          VEN
# 199               Vietnam          VNM
# 201                 Samoa          WSM
# 202           Yemen, Rep.          YEM
# 203          South Africa          ZAF
#
#                              Indicator Name  Indicator Code      1960  \
# 1    CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC  0.046057
# 2    CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC  0.100835
# 3    CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC  1.258195
# 5    CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC  0.119037
# 6    CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC  2.383343
# ...

# %%
Group_by_Region_1.sum(axis=1)
# Out:
# 1        17.627081
# 2        81.129749
# 3       195.931080
# 5      3589.156020
# 6       418.265328
#           ...
# 197     671.102860
# 199      84.499720
# 201      81.775619
# 202      52.171329
# 203     884.701146
# Length: 141, dtype: float64

# %%
Group_by_Region_1
# Out:
#              Country Name Country Code  \
# 1             Afghanistan          AFG
# 2                  Angola          AGO
# 3                 Albania          ALB
# 5    United Arab Emirates          ARE
# 6               Argentina          ARG
# ..                    ...          ...
# 197         Venezuela, RB          VEN
# 199               Vietnam          VNM
# 201                 Samoa          WSM
# 202           Yemen, Rep.          YEM
# 203          South Africa          ZAF
#
#                              Indicator Name  Indicator Code      1960  \
# 1    CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC  0.046057
# 2    CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC  0.100835
# 3    CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC  1.258195
# 5    CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC  0.119037
# 6    CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC  2.383343
# ...

# %%
Top_10 = Group_by_Region_1.sort_values(by='Total_emissions', ascending=False)

# %%
Top_10
# Out:
#                  Country Name Country Code  \
# 156                     Qatar          QAT
# 5        United Arab Emirates          ARE
# 112                Luxembourg          LUX
# 19                    Bahrain          BHR
# 28          Brunei Darussalam          BRN
# ..                        ...          ...
# 136                     Niger          NER
# 31   Central African Republic          CAF
# 159                    Rwanda          RWA
# 59                   Ethiopia          ETH
# 179                      Chad          TCD
#
#                              Indicator Name  Indicator Code       1960  \
# 156  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   3.714750
# 5    CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   0.119037
# 112  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC  36.685183
# 19   CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   3.544435
# 28   CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   4.084069
# ...

# %%
Top_10_Countries = Top_10.head(10)

# %%
Top_10_Countries
# Out:
#              Country Name Country Code  \
# 156                 Qatar          QAT
# 5    United Arab Emirates          ARE
# 112            Luxembourg          LUX
# 19                Bahrain          BHR
# 28      Brunei Darussalam          BRN
# 194         United States          USA
# 158    Russian Federation          RUS
# 32                 Canada          CAN
# 10              Australia          AUS
# 20           Bahamas, The          BHS
#
#                              Indicator Name  Indicator Code       1960  \
# 156  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   3.714750
# 5    CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   0.119037
# 112  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC  36.685183
# 19   CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   3.544435
# 28   CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   4.084069
# 194  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC  15.999779
# ...

# %%
#The Country with the Highest CO2 emissions/ capita was Qatar. More oil producing countries are in top 10:Bahrain, Brunei, United Arab Emirates

# %%
Top_10_Countries.groupby('Country Name').sum()['Total_emissions'].plot.bar()
plt.xlabel('Country Name')
plt.ylabel('metric tons/ capita')
plt.title('Total CO2 emissions/capita 1960-2018 by country Top 10')
# Out:
# Text(0.5, 1.0, 'Total CO2 emissions/capita 1960-2018 by country Top 10')
