# %%
import pandas as pd
import numpy as np

# %%
#Import Data from Flat file

# %%
CO2_emissions = pd.read_csv(r'C:\Users\Bogdan Nacu\Downloads\CO2_Income_by_country\country_wise_CO2_emissions.csv')
CO2_emissions
# Out:
#                     Country Name Country Code  \
# 0                          Aruba          ABW
# 1    Africa Eastern and Southern          AFE
# 2                    Afghanistan          AFG
# 3     Africa Western and Central          AFW
# 4                         Angola          AGO
# ..                           ...          ...
# 261                       Kosovo          XKX
# 262                  Yemen, Rep.          YEM
# 263                 South Africa          ZAF
# 264                       Zambia          ZMB
# 265                     Zimbabwe          ZWE
#
#                              Indicator Name  Indicator Code        1960  \
# 0    CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC  204.631696
# 1    CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC    0.906060
# 2    CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC    0.046057
# 3    CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC    0.090880
# ...

# %%
#Create pandas DataFrame

# %%
pd.DataFrame(CO2_emissions)
# Out:
#                     Country Name Country Code  \
# 0                          Aruba          ABW
# 1    Africa Eastern and Southern          AFE
# 2                    Afghanistan          AFG
# 3     Africa Western and Central          AFW
# 4                         Angola          AGO
# ..                           ...          ...
# 261                       Kosovo          XKX
# 262                  Yemen, Rep.          YEM
# 263                 South Africa          ZAF
# 264                       Zambia          ZMB
# 265                     Zimbabwe          ZWE
#
#                              Indicator Name  Indicator Code        1960  \
# 0    CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC  204.631696
# 1    CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC    0.906060
# 2    CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC    0.046057
# 3    CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC    0.090880
# ...

# %%
CO2_emissions.head()
# Out:
#                   Country Name Country Code  \
# 0                        Aruba          ABW
# 1  Africa Eastern and Southern          AFE
# 2                  Afghanistan          AFG
# 3   Africa Western and Central          AFW
# 4                       Angola          AGO
#
#                            Indicator Name  Indicator Code        1960  \
# 0  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC  204.631696
# 1  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC    0.906060
# 2  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC    0.046057
# 3  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC    0.090880
# 4  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC    0.100835
#
#          1961        1962        1963        1964        1965  ...      2011  \
# 0  208.837879  226.081890  214.785217  207.626699  185.213644  ...       NaN
# 1    0.922474    0.930816    0.940570    0.996033    1.047280  ...  1.005338
# ...

# %%
Country_income = pd.read_csv(r'C:\Users\Bogdan Nacu\Downloads\CO2_Income_by_country\country_wise_income_group.csv')
Country_income
# Out:
#      Country Name Country Code                      Region  \
# 0           Aruba          ABW   Latin America & Caribbean
# 1     Afghanistan          AFG                  South Asia
# 2          Angola          AGO          Sub-Saharan Africa
# 3         Albania          ALB       Europe & Central Asia
# 4         Andorra          AND       Europe & Central Asia
# ..            ...          ...                         ...
# 243         Samoa          WSM         East Asia & Pacific
# 244   Yemen, Rep.          YEM  Middle East & North Africa
# 245  South Africa          ZAF          Sub-Saharan Africa
# 246        Zambia          ZMB          Sub-Saharan Africa
# 247      Zimbabwe          ZWE          Sub-Saharan Africa
#
#               IncomeGroup                                       SpecialNotes  \
# 0    High income: nonOECD  SNA data for 2000-2011 are updated from offici...
# 1              Low income  Fiscal year end: March 20; reporting period fo...
# ...

# %%
pd.DataFrame(Country_income)
# Out:
#      Country Name Country Code                      Region  \
# 0           Aruba          ABW   Latin America & Caribbean
# 1     Afghanistan          AFG                  South Asia
# 2          Angola          AGO          Sub-Saharan Africa
# 3         Albania          ALB       Europe & Central Asia
# 4         Andorra          AND       Europe & Central Asia
# ..            ...          ...                         ...
# 243         Samoa          WSM         East Asia & Pacific
# 244   Yemen, Rep.          YEM  Middle East & North Africa
# 245  South Africa          ZAF          Sub-Saharan Africa
# 246        Zambia          ZMB          Sub-Saharan Africa
# 247      Zimbabwe          ZWE          Sub-Saharan Africa
#
#               IncomeGroup                                       SpecialNotes  \
# 0    High income: nonOECD  SNA data for 2000-2011 are updated from offici...
# 1              Low income  Fiscal year end: March 20; reporting period fo...
# ...

# %%
Country_income.head()
# Out:
#   Country Name Country Code                     Region           IncomeGroup  \
# 0        Aruba          ABW  Latin America & Caribbean  High income: nonOECD
# 1  Afghanistan          AFG                 South Asia            Low income
# 2       Angola          AGO         Sub-Saharan Africa   Upper middle income
# 3      Albania          ALB      Europe & Central Asia   Upper middle income
# 4      Andorra          AND      Europe & Central Asia  High income: nonOECD
#
#                                         SpecialNotes  Unnamed: 5
# 0  SNA data for 2000-2011 are updated from offici...         NaN
# 1  Fiscal year end: March 20; reporting period fo...         NaN
# 2  April 2013 database update: Based on IMF data,...         NaN
# 3                                                NaN         NaN
# 4                                                NaN         NaN

# %%
pwd
# Out:
# 'C:\\Users\\Bogdan Nacu'

# %%
import seaborn as sns

# %%
#Use Numpy functions

# %%
CO2_emissions[['1960', '2018']].apply(np.sum)
# Out:
# 1960    641.524584
# 2018    993.730805
# dtype: float64

# %%
CO2_emissions['Sum_60_18'] = CO2_emissions[['1960', '2018']].apply(np.sum, axis=1)

# %%
CO2_emissions.head()
# Out:
#                   Country Name Country Code  \
# 0                        Aruba          ABW
# 1  Africa Eastern and Southern          AFE
# 2                  Afghanistan          AFG
# 3   Africa Western and Central          AFW
# 4                       Angola          AGO
#
#                            Indicator Name  Indicator Code        1960  \
# 0  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC  204.631696
# 1  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC    0.906060
# 2  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC    0.046057
# 3  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC    0.090880
# 4  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC    0.100835
#
#          1961        1962        1963        1964        1965  ...      2012  \
# 0  208.837879  226.081890  214.785217  207.626699  185.213644  ...       NaN
# 1    0.922474    0.930816    0.940570    0.996033    1.047280  ...  1.021646
# ...

# %%
#Define a Custom function to create reusable code

# %%
def Sum_60_18(CO2_emissions):
    Sum_60_18 = CO2_emissions['1960'] + CO2_emissions['2018']
    return Sum_60_18

# %%
Sum_60_18(CO2_emissions)
# Out:
# 0            NaN
# 1       1.839601
# 2       0.246208
# 3       0.606424
# 4       0.988216
#          ...
# 261          NaN
# 262     0.337720
# 263    13.223868
# 264          NaN
# 265          NaN
# Length: 266, dtype: float64

# %%
CO2_emissions['Sum_60_18'] = CO2_emissions.apply(Sum_60_18, axis=1)

# %%
CO2_emissions
# Out:
#                     Country Name Country Code  \
# 0                          Aruba          ABW
# 1    Africa Eastern and Southern          AFE
# 2                    Afghanistan          AFG
# 3     Africa Western and Central          AFW
# 4                         Angola          AGO
# ..                           ...          ...
# 261                       Kosovo          XKX
# 262                  Yemen, Rep.          YEM
# 263                 South Africa          ZAF
# 264                       Zambia          ZMB
# 265                     Zimbabwe          ZWE
#
#                              Indicator Name  Indicator Code        1960  \
# 0    CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC  204.631696
# 1    CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC    0.906060
# 2    CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC    0.046057
# 3    CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC    0.090880
# ...

# %%
CO2_emissions.info
# Out:
# <bound method DataFrame.info of                     Country Name Country Code  \
# 0                          Aruba          ABW
# 1    Africa Eastern and Southern          AFE
# 2                    Afghanistan          AFG
# 3     Africa Western and Central          AFW
# 4                         Angola          AGO
# ..                           ...          ...
# 261                       Kosovo          XKX
# 262                  Yemen, Rep.          YEM
# 263                 South Africa          ZAF
# 264                       Zambia          ZMB
# 265                     Zimbabwe          ZWE
#
#                              Indicator Name  Indicator Code        1960  \
# 0    CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC  204.631696
# 1    CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC    0.906060
# 2    CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC    0.046057
# 3    CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC    0.090880
# ...

# %%
Country_income.info
# Out:
# <bound method DataFrame.info of      Country Name Country Code                      Region  \
# 0           Aruba          ABW   Latin America & Caribbean
# 1     Afghanistan          AFG                  South Asia
# 2          Angola          AGO          Sub-Saharan Africa
# 3         Albania          ALB       Europe & Central Asia
# 4         Andorra          AND       Europe & Central Asia
# ..            ...          ...                         ...
# 243         Samoa          WSM         East Asia & Pacific
# 244   Yemen, Rep.          YEM  Middle East & North Africa
# 245  South Africa          ZAF          Sub-Saharan Africa
# 246        Zambia          ZMB          Sub-Saharan Africa
# 247      Zimbabwe          ZWE          Sub-Saharan Africa
#
#               IncomeGroup                                       SpecialNotes  \
# 0    High income: nonOECD  SNA data for 2000-2011 are updated from offici...
# ...

# %%
#Indexing

# %%
CO2_emissions.index
# Out:
# RangeIndex(start=0, stop=266, step=1)

# %%
Country_income.index
# Out:
# RangeIndex(start=0, stop=248, step=1)

# %%
CO2_emissions.iloc[0, 6]
# Out:
# 226.08189

# %%
Country_income[0:5]
# Out:
#   Country Name Country Code                     Region           IncomeGroup  \
# 0        Aruba          ABW  Latin America & Caribbean  High income: nonOECD
# 1  Afghanistan          AFG                 South Asia            Low income
# 2       Angola          AGO         Sub-Saharan Africa   Upper middle income
# 3      Albania          ALB      Europe & Central Asia   Upper middle income
# 4      Andorra          AND      Europe & Central Asia  High income: nonOECD
#
#                                         SpecialNotes  Unnamed: 5
# 0  SNA data for 2000-2011 are updated from offici...         NaN
# 1  Fiscal year end: March 20; reporting period fo...         NaN
# 2  April 2013 database update: Based on IMF data,...         NaN
# 3                                                NaN         NaN
# 4                                                NaN         NaN

# %%
CO2_emissions[0:20][['Country Name', '1960', '1980', '2000', '2018']]
# Out:
#                    Country Name        1960        1980       2000       2018
# 0                         Aruba  204.631696  174.694594        NaN        NaN
# 1   Africa Eastern and Southern    0.906060    1.235911   0.900399   0.933541
# 2                   Afghanistan    0.046057    0.131783   0.037055   0.200151
# 3    Africa Western and Central    0.090880    0.634541   0.447244   0.515544
# 4                        Angola    0.100835    0.640966   0.754476   0.887380
# 5                       Albania    1.258195    1.935058   1.026213   1.939732
# 6                       Andorra         NaN         NaN   7.952286   5.973405
# 7                    Arab World    0.609268    3.091803   3.163305   4.438716
# 8          United Arab Emirates    0.119037   36.198563  26.974535  20.797498
# 9                     Argentina    2.383343    3.897888   3.577628   3.987234
# 10                      Armenia         NaN         NaN   1.159761   1.880246
# ...

# %%
#Drop duplicates

# %%
CO2_emissions.drop_duplicates
# Out:
# <bound method DataFrame.drop_duplicates of                     Country Name Country Code  \
# 0                          Aruba          ABW
# 1    Africa Eastern and Southern          AFE
# 2                    Afghanistan          AFG
# 3     Africa Western and Central          AFW
# 4                         Angola          AGO
# ..                           ...          ...
# 261                       Kosovo          XKX
# 262                  Yemen, Rep.          YEM
# 263                 South Africa          ZAF
# 264                       Zambia          ZMB
# 265                     Zimbabwe          ZWE
#
#                              Indicator Name  Indicator Code        1960  \
# 0    CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC  204.631696
# 1    CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC    0.906060
# 2    CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC    0.046057
# 3    CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC    0.090880
# ...

# %%
Country_income.drop_duplicates
# Out:
# <bound method DataFrame.drop_duplicates of      Country Name Country Code                      Region  \
# 0           Aruba          ABW   Latin America & Caribbean
# 1     Afghanistan          AFG                  South Asia
# 2          Angola          AGO          Sub-Saharan Africa
# 3         Albania          ALB       Europe & Central Asia
# 4         Andorra          AND       Europe & Central Asia
# ..            ...          ...                         ...
# 243         Samoa          WSM         East Asia & Pacific
# 244   Yemen, Rep.          YEM  Middle East & North Africa
# 245  South Africa          ZAF          Sub-Saharan Africa
# 246        Zambia          ZMB          Sub-Saharan Africa
# 247      Zimbabwe          ZWE          Sub-Saharan Africa
#
#               IncomeGroup                                       SpecialNotes  \
# 0    High income: nonOECD  SNA data for 2000-2011 are updated from offici...
# ...

# %%
#Replacing missing values, Handling Nulls

# %%
CO2_emissions.isnull().sum()
# Out:
# Country Name        0
# Country Code        0
# Indicator Name      0
# Indicator Code      0
# 1960               63
#                  ...
# 2018               27
# 2019              266
# 2020              266
# Sum_60_18          73
# sum_CO2            73
# Length: 67, dtype: int64

# %%
Country_income.isnull().sum()
# Out:
# Country Name      0
# Country Code      0
# Region           33
# IncomeGroup      33
# SpecialNotes     79
# Unnamed: 5      248
# dtype: int64

# %%
CO2_emissions.dropna(axis=1, how='all').shape
# Out:
# (266, 63)

# %%
CO2_emissions.dropna(axis=1, how='all', inplace = True)

# %%
CO2_emissions.dropna(thresh=5)
# Out:
#                     Country Name Country Code  \
# 0                          Aruba          ABW
# 1    Africa Eastern and Southern          AFE
# 2                    Afghanistan          AFG
# 3     Africa Western and Central          AFW
# 4                         Angola          AGO
# ..                           ...          ...
# 260                        Samoa          WSM
# 262                  Yemen, Rep.          YEM
# 263                 South Africa          ZAF
# 264                       Zambia          ZMB
# 265                     Zimbabwe          ZWE
#
#                              Indicator Name  Indicator Code        1960  \
# 0    CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC  204.631696
# 1    CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC    0.906060
# 2    CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC    0.046057
# 3    CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC    0.090880
# ...

# %%
Country_income.dropna(axis=1, how='all', inplace = True)

# %%
Country_income
# Out:
#      Country Name Country Code                      Region  \
# 0           Aruba          ABW   Latin America & Caribbean
# 1     Afghanistan          AFG                  South Asia
# 2          Angola          AGO          Sub-Saharan Africa
# 3         Albania          ALB       Europe & Central Asia
# 4         Andorra          AND       Europe & Central Asia
# ..            ...          ...                         ...
# 243         Samoa          WSM         East Asia & Pacific
# 244   Yemen, Rep.          YEM  Middle East & North Africa
# 245  South Africa          ZAF          Sub-Saharan Africa
# 246        Zambia          ZMB          Sub-Saharan Africa
# 247      Zimbabwe          ZWE          Sub-Saharan Africa
#
#               IncomeGroup                                       SpecialNotes
# 0    High income: nonOECD  SNA data for 2000-2011 are updated from offici...
# 1              Low income  Fiscal year end: March 20; reporting period fo...
# ...

# %%
CO2_emissions.fillna(method='bfill', axis=1).fillna('No Data Available')
# Out:
#                     Country Name Country Code  \
# 0                          Aruba          ABW
# 1    Africa Eastern and Southern          AFE
# 2                    Afghanistan          AFG
# 3     Africa Western and Central          AFW
# 4                         Angola          AGO
# ..                           ...          ...
# 261                       Kosovo          XKX
# 262                  Yemen, Rep.          YEM
# 263                 South Africa          ZAF
# 264                       Zambia          ZMB
# 265                     Zimbabwe          ZWE
#
#                              Indicator Name  Indicator Code  \
# 0    CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC
# 1    CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC
# 2    CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC
# 3    CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC
# 4    CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC
# ...

# %%
Country_income.fillna(method='bfill', axis=1).fillna('No Data Available')
# Out:
#      Country Name Country Code                      Region  \
# 0           Aruba          ABW   Latin America & Caribbean
# 1     Afghanistan          AFG                  South Asia
# 2          Angola          AGO          Sub-Saharan Africa
# 3         Albania          ALB       Europe & Central Asia
# 4         Andorra          AND       Europe & Central Asia
# ..            ...          ...                         ...
# 243         Samoa          WSM         East Asia & Pacific
# 244   Yemen, Rep.          YEM  Middle East & North Africa
# 245  South Africa          ZAF          Sub-Saharan Africa
# 246        Zambia          ZMB          Sub-Saharan Africa
# 247      Zimbabwe          ZWE          Sub-Saharan Africa
#
#               IncomeGroup                                       SpecialNotes
# 0    High income: nonOECD  SNA data for 2000-2011 are updated from offici...
# 1              Low income  Fiscal year end: March 20; reporting period fo...
# ...
